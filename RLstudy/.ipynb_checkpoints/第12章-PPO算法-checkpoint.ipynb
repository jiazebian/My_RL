# %%
import gymnasium as gym
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import rl_utils
import random

class PolicyNet(torch.nn.Module):#actor
    def __init__(self, state_dim, hidden_dim, action_dim):
        super(PolicyNet, self).__init__()
        self.fc1 = torch.nn.Linear(state_dim, hidden_dim)
        self.fc2 = torch.nn.Linear(hidden_dim, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        return F.softmax(self.fc2(x), dim=1)#像是分类问题，输出的是选择每个动作的概率


class ValueNet(torch.nn.Module):#critic
    def __init__(self, state_dim, hidden_dim):
        super(ValueNet, self).__init__()
        self.fc1 = torch.nn.Linear(state_dim, hidden_dim)
        self.fc2 = torch.nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        return self.fc2(x)


class PPO:
    ''' PPO算法,采用截断方式 '''
    def __init__(self, state_dim, hidden_dim, action_dim, actor_lr, critic_lr,
                 lmbda, epochs, eps, gamma, device):
        self.actor = PolicyNet(state_dim, hidden_dim, action_dim).to(device)
        self.critic = ValueNet(state_dim, hidden_dim).to(device)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(),
                                                lr=actor_lr)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(),
                                                 lr=critic_lr)
        self.gamma = gamma
        self.lmbda = lmbda#gamma*lmbda是真正的回合间的奖励折扣
        self.epochs = epochs  #训练批次
        self.eps = eps  # PPO中截断范围的参数
        self.device = device

    def take_action(self, state):#state是一个四元列表
        state = torch.tensor([state], dtype=torch.float).to(self.device) #形状为(1,4)的二维张量
        probs = self.actor(state)#让演员策略网络根据情况输出动作概率组
        action_dist = torch.distributions.Categorical(probs)#用 probs 构造一个类别分布（Categorical distribution，适用于离散动作）
        action = action_dist.sample()#从这个分布里随机采样一个动作（按概率采样，不是取最大概率）
        return action.item()#把只包含一个数值的张量转换成 Python 标量（比如 int）

    def update(self, transition_dict):
        states = torch.tensor(transition_dict['states'],
                              dtype=torch.float).to(self.device)
        actions = torch.tensor(transition_dict['actions']).view(-1, 1).to(
            self.device)
        rewards = torch.tensor(transition_dict['rewards'],
                               dtype=torch.float).view(-1, 1).to(self.device)
        next_states = torch.tensor(transition_dict['next_states'],
                                   dtype=torch.float).to(self.device)
        dones = torch.tensor(transition_dict['dones'],
                             dtype=torch.float).view(-1, 1).to(self.device)
        td_target = rewards + self.gamma * self.critic(next_states) * (1 -dones) #r+γ*V(t+1)
        td_delta = td_target - self.critic(states)#TD误差，r(s,a)+γ*V(st+1)-V(st)
        #评论员网络既要评论本状态的价值，又要评论下个状态的价值
        advantage = rl_utils.compute_advantage(self.gamma, self.lmbda,td_delta.cpu()).to(self.device)
        #advantage（这里用 GAE 计算得到的）是对未来多个时步的TD误差加权累积,让数据更加平滑,同时优势函数指的是在s状态采取a动作的好坏，正就是好，负就是坏
        old_log_probs = torch.log(self.actor(states).gather(1,actions)).detach()
        # 计算“旧策略(old policy)对已选动作的对数概率 log π_old(a|s)”，在下面的训练过程中不变
        for _ in range(self.epochs):
            log_probs = torch.log(self.actor(states).gather(1, actions))
            ratio = torch.exp(log_probs - old_log_probs) #log( (pΘ'(at|st)/(pΘ(at|st)) )，重要性采样
            surr1 = ratio * advantage #log( (pΘ'(at|st)/(pΘ(at|st)) ) *A（st,at)
            surr2 = torch.clamp(ratio, 1 - self.eps,1 + self.eps) * advantage  # 截断
            actor_loss = torch.mean(-torch.min(surr1, surr2))# 我们希望最大化期望目标J(Θ)，但是pytorch的优化器只能最小化一个损失，所以取负号
            #min 让最终使用的那一项永远是更保守（更小）的 surrogate，遇到好的，不要过于好，遇到坏的，不要过于坏
            critic_loss = torch.mean(F.mse_loss(self.critic(states), td_target.detach()))#最小化 MSE(V(s), td_target)，把 td_target 当作“常数目标”来回归
            self.actor_optimizer.zero_grad()
            self.critic_optimizer.zero_grad()
            actor_loss.backward()
            critic_loss.backward()
            self.actor_optimizer.step()
            self.critic_optimizer.step()

# %%
actor_lr = 1e-3
critic_lr = 1e-2
num_episodes = 500 #总回合数
hidden_dim = 128 #隐藏层大小
gamma = 0.98 #折扣因子γ=gamma*lmbda
lmbda = 0.95 
epochs = 10 #训练批次
eps = 0.2  #PPO中截断范围的参数，设置变化的上限
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")

env_name = 'CartPole-v0'
env = gym.make(env_name)

# 全局随机种子（保持）
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)
# 给 action_space / observation_space 也设种子（向后兼容）
env.action_space.seed(0)
env.observation_space.seed(0)

state_dim  = env.observation_space.shape[0] #4
action_dim = env.action_space.n #2
agent = PPO(state_dim, hidden_dim, action_dim, actor_lr, critic_lr, lmbda,
            epochs, eps, gamma, device)

return_list = rl_utils.train_on_policy_agent(env, agent, num_episodes) #在线策略学习
# Out:
# /home/bian/anaconda3/envs/rl/lib/python3.10/site-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Iteration 0:   0%|                                                                                                             | 0/50 [00:00<?, ?it/s]/tmp/ipykernel_1133/64045694.py:48: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   state = torch.tensor([state], dtype=torch.float).to(self.device) #形状为(1,4)的二维张量
# Iteration 0: 100%|████████████████████████████████████████████████████████████████████████| 50/50 [00:11<00:00,  4.22it/s, episode=50, return=106.600]
# Iteration 1: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.87it/s, episode=100, return=181.600]
# Iteration 2: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:18<00:00,  2.73it/s, episode=150, return=191.400]
# Iteration 3: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.80it/s, episode=200, return=200.000]
# Iteration 4: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.80it/s, episode=250, return=200.000]
# Iteration 5: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.86it/s, episode=300, return=182.300]
# Iteration 6: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:18<00:00,  2.74it/s, episode=350, return=200.000]
# Iteration 7: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:16<00:00,  2.95it/s, episode=400, return=200.000]
# Iteration 8: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.89it/s, episode=450, return=200.000]
# Iteration 9: 100%|███████████████████████████████████████████████████████████████████████| 50/50 [00:18<00:00,  2.75it/s, episode=500, return=200.000]

# %%
episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PPO on {}'.format(env_name))
plt.show()

mv_return = rl_utils.moving_average(return_list, 9)
plt.plot(episodes_list, mv_return)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PPO on {}'.format(env_name))
plt.show()

# %%
import gymnasium as gym
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import rl_utils
import random
class PolicyNetContinuous(torch.nn.Module):
    def __init__(self, state_dim, hidden_dim, action_dim):#输出动作分布的参数，动作服从高斯（正态）分布
        super(PolicyNetContinuous, self).__init__()#父类torch.nn.Module的初始化
        self.fc1 = torch.nn.Linear(state_dim, hidden_dim)
        self.fc_mu = torch.nn.Linear(hidden_dim, action_dim)#均值
        self.fc_std = torch.nn.Linear(hidden_dim, action_dim)#标准差

    def forward(self, x):
        x = F.relu(self.fc1(x))
        mu = 2.0 * torch.tanh(self.fc_mu(x))#限制在【-2，2】
        std = F.softplus(self.fc_std(x))#限制为正
        return mu, std


class PPOContinuous:
    ''' 处理连续动作的PPO算法 '''
    def __init__(self, state_dim, hidden_dim, action_dim, actor_lr, critic_lr,
                 lmbda, epochs, eps, gamma, device):
        self.actor = PolicyNetContinuous(state_dim, hidden_dim,
                                         action_dim).to(device)
        self.critic = ValueNet(state_dim, hidden_dim).to(device)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(),
                                                lr=actor_lr)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(),
                                                 lr=critic_lr)
        self.gamma = gamma
        self.lmbda = lmbda
        self.epochs = epochs
        self.eps = eps
        self.device = device

    def take_action(self, state):
        state = torch.tensor([state], dtype=torch.float).to(self.device)
        mu, sigma = self.actor(state)#均值，方差
        action_dist = torch.distributions.Normal(mu, sigma)#返回Normal类型的数据
        action = action_dist.sample()#采样一次，得到torch张量
        return [action.item()]#返回一个数字，即要执行的动作

    def update(self, transition_dict):
        states = torch.tensor(transition_dict['states'],
                              dtype=torch.float).to(self.device)
        actions = torch.tensor(transition_dict['actions'],
                               dtype=torch.float).view(-1, 1).to(self.device)
        rewards = torch.tensor(transition_dict['rewards'],
                               dtype=torch.float).view(-1, 1).to(self.device)
        next_states = torch.tensor(transition_dict['next_states'],
                                   dtype=torch.float).to(self.device)
        dones = torch.tensor(transition_dict['dones'],
                             dtype=torch.float).view(-1, 1).to(self.device)
        rewards = (rewards + 8.0) / 8.0  # 和TRPO一样,对奖励进行修改,方便训练
        td_target = rewards + self.gamma * self.critic(next_states) * (1 -
                                                                       dones)
        td_delta = td_target - self.critic(states)
        advantage = rl_utils.compute_advantage(self.gamma, self.lmbda,
                                               td_delta.cpu()).to(self.device)
        mu, std = self.actor(states)
        action_dists = torch.distributions.Normal(mu.detach(), std.detach())
        # 动作是正态分布
        old_log_probs = action_dists.log_prob(actions)

        for _ in range(self.epochs):
            mu, std = self.actor(states)
            action_dists = torch.distributions.Normal(mu, std)
            log_probs = action_dists.log_prob(actions)
            ratio = torch.exp(log_probs - old_log_probs)
            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1 - self.eps, 1 + self.eps) * advantage
            actor_loss = torch.mean(-torch.min(surr1, surr2))
            critic_loss = torch.mean(
                F.mse_loss(self.critic(states), td_target.detach()))
            self.actor_optimizer.zero_grad()
            self.critic_optimizer.zero_grad()
            actor_loss.backward()
            critic_loss.backward()
            self.actor_optimizer.step()
            self.critic_optimizer.step()

# %%
actor_lr = 1e-4
critic_lr = 5e-3
num_episodes = 2000
hidden_dim = 128
gamma = 0.9
lmbda = 0.9
epochs = 10
eps = 0.2
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")

env_name = 'Pendulum-v1'
env = gym.make(env_name)
# 全局随机种子（保持）
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)
# 给 action_space / observation_space 也设种子（向后兼容）
env.action_space.seed(0)
env.observation_space.seed(0)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]  # 连续动作空间
agent = PPOContinuous(state_dim, hidden_dim, action_dim, actor_lr, critic_lr,
                      lmbda, epochs, eps, gamma, device)

return_list = rl_utils.train_on_policy_agent(env, agent, num_episodes)

# Iteration 0: 100%|██████████| 200/200 [02:15<00:00,  1.47it/s, episode=200,
# return=-984.137]
# Iteration 1: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=400,
# return=-895.332]
# Iteration 2: 100%|██████████| 200/200 [02:14<00:00,  1.48it/s, episode=600,
# return=-518.916]
# Iteration 3: 100%|██████████| 200/200 [02:19<00:00,  1.44it/s, episode=800,
# return=-602.183]
# Iteration 4: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=1000,
# return=-392.104]
# Iteration 5: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=1200,
# return=-259.206]
# Iteration 6: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=1400,
# return=-221.772]
# Iteration 7: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=1600,
# return=-293.515]
# Iteration 8: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=1800,
# return=-371.194]
# Iteration 9: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=2000,
# return=-248.958]
# Out:
# Iteration 0:   0%|                                                                             | 0/200 [00:00<?, ?it/s]C:\Users\Jaco Bian\AppData\Local\Temp\ipykernel_25180\697691486.py:40: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ..\torch\csrc\utils\tensor_new.cpp:204.)
#   state = torch.tensor([state], dtype=torch.float).to(self.device)
# action_dist Normal(loc: tensor([[-0.3333]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5471]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8392]], device='cuda:0')
# action.item() -0.8392000198364258
# action_dist Normal(loc: tensor([[-0.4266]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5505]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3270]], device='cuda:0')
# action.item() -0.3270278573036194
# action_dist Normal(loc: tensor([[-0.5409]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5734]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.9179]], device='cuda:0')
# action.item() 0.917858362197876
# action_dist Normal(loc: tensor([[-0.6030]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6110]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3882]], device='cuda:0')
# action.item() -0.38820382952690125
# action_dist Normal(loc: tensor([[-0.6320]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6333]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8506]], device='cuda:0')
# action.item() -0.8506343364715576
# action_dist Normal(loc: tensor([[-0.6414]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6508]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4988]], device='cuda:0')
# action.item() -0.4987761378288269
# action_dist Normal(loc: tensor([[-0.6393]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6657]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1510]], device='cuda:0')
# action.item() -1.1510086059570312
# action_dist Normal(loc: tensor([[-0.5767]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6858]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4112]], device='cuda:0')
# action.item() -0.41123372316360474
# action_dist Normal(loc: tensor([[-0.5159]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7165]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.3721]], device='cuda:0')
# action.item() -1.3720502853393555
# action_dist Normal(loc: tensor([[-0.5086]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7627]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1722]], device='cuda:0')
# action.item() 0.1722276210784912
# action_dist Normal(loc: tensor([[-0.5094]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8274]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9544]], device='cuda:0')
# action.item() -0.9544076919555664
# action_dist Normal(loc: tensor([[-0.5137]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8899]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3118]], device='cuda:0')
# action.item() -0.3117566704750061
# action_dist Normal(loc: tensor([[-0.5189]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9533]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3728]], device='cuda:0')
# action.item() 0.3727833032608032
# action_dist Normal(loc: tensor([[-0.5276]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0026]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.2908]], device='cuda:0')
# action.item() -1.2908070087432861
# action_dist Normal(loc: tensor([[-0.5048]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0163]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0834]], device='cuda:0')
# action.item() 0.08337485790252686
# action_dist Normal(loc: tensor([[-0.4601]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0218]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0909]], device='cuda:0')
# action.item() -1.0908719301223755
# action_dist Normal(loc: tensor([[-0.4001]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9905]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1833]], device='cuda:0')
# action.item() 0.18330428004264832
# action_dist Normal(loc: tensor([[-0.3480]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9608]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4108]], device='cuda:0')
# action.item() 0.41076016426086426
# action_dist Normal(loc: tensor([[-0.2937]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9317]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3538]], device='cuda:0')
# action.item() -0.3538384437561035
# action_dist Normal(loc: tensor([[-0.2445]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8951]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.6077]], device='cuda:0')
# action.item() 0.6076603531837463
# action_dist Normal(loc: tensor([[-0.2551]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8590]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.2353]], device='cuda:0')
# action.item() -1.2353113889694214
# action_dist Normal(loc: tensor([[-0.2644]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8084]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4050]], device='cuda:0')
# action.item() 0.40500879287719727
# action_dist Normal(loc: tensor([[-0.1740]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7940]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7586]], device='cuda:0')
# action.item() -0.7586230039596558
# action_dist Normal(loc: tensor([[-0.0515]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7869]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6374]], device='cuda:0')
# action.item() -0.6373899579048157
# action_dist Normal(loc: tensor([[-0.1154]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7906]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7806]], device='cuda:0')
# action.item() -0.7806212306022644
# action_dist Normal(loc: tensor([[-0.1575]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7800]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.8557]], device='cuda:0')
# action.item() 0.8557127714157104
# action_dist Normal(loc: tensor([[-0.1239]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7722]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0557]], device='cuda:0')
# action.item() -0.05565977096557617
# action_dist Normal(loc: tensor([[-0.1631]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7776]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3492]], device='cuda:0')
# action.item() 0.34919482469558716
# action_dist Normal(loc: tensor([[-0.1748]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7717]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3900]], device='cuda:0')
# action.item() -0.38996565341949463
# action_dist Normal(loc: tensor([[-0.2010]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7669]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.8837]], device='cuda:0')
# action.item() 0.8836753368377686
# action_dist Normal(loc: tensor([[-0.2067]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7645]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0973]], device='cuda:0')
# action.item() -1.0973320007324219
# action_dist Normal(loc: tensor([[-0.1878]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7585]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6906]], device='cuda:0')
# action.item() -0.6906198263168335
# action_dist Normal(loc: tensor([[-0.1442]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7437]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5761]], device='cuda:0')
# action.item() -0.5760865211486816
# action_dist Normal(loc: tensor([[-0.0774]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7200]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1997]], device='cuda:0')
# action.item() -0.19973164796829224
# action_dist Normal(loc: tensor([[-0.0083]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6978]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5152]], device='cuda:0')
# action.item() -0.5152263641357422
# action_dist Normal(loc: tensor([[0.0454]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6780]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0567]], device='cuda:0')
# action.item() -0.05666534602642059
# action_dist Normal(loc: tensor([[0.0776]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6639]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1073]], device='cuda:0')
# action.item() -0.1073351800441742
# action_dist Normal(loc: tensor([[0.0976]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6537]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0934]], device='cuda:0')
# action.item() 0.09342315793037415
# action_dist Normal(loc: tensor([[0.1025]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6440]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3614]], device='cuda:0')
# action.item() 0.36142390966415405
# action_dist Normal(loc: tensor([[0.0828]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6349]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.9668]], device='cuda:0')
# action.item() 0.9668043851852417
# action_dist Normal(loc: tensor([[0.0612]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6278]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0906]], device='cuda:0')
# action.item() -0.09059879183769226
# action_dist Normal(loc: tensor([[-0.0068]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6127]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0630]], device='cuda:0')
# action.item() 0.06295573711395264
# action_dist Normal(loc: tensor([[-0.1308]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6025]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1116]], device='cuda:0')
# action.item() -1.111605167388916
# action_dist Normal(loc: tensor([[-0.1727]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5833]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0859]], device='cuda:0')
# action.item() -0.08590783178806305
# action_dist Normal(loc: tensor([[-0.2952]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5471]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1577]], device='cuda:0')
# action.item() -0.15771183371543884
# action_dist Normal(loc: tensor([[-0.4505]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5482]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0977]], device='cuda:0')
# action.item() -0.09769997000694275
# action_dist Normal(loc: tensor([[-0.5790]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5832]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.9583]], device='cuda:0')
# action.item() -1.9583027362823486
# action_dist Normal(loc: tensor([[-0.6194]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6011]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0843]], device='cuda:0')
# action.item() -1.084267020225525
# action_dist Normal(loc: tensor([[-0.6325]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6272]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6645]], device='cuda:0')
# action.item() -0.6645184755325317
# action_dist Normal(loc: tensor([[-0.6338]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6533]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4567]], device='cuda:0')
# action.item() 0.45670872926712036
# action_dist Normal(loc: tensor([[-0.6041]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6764]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.7116]], device='cuda:0')
# action.item() 0.7116372585296631
# action_dist Normal(loc: tensor([[-0.5141]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7093]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.8651]], device='cuda:0')
# action.item() -1.865123987197876
# action_dist Normal(loc: tensor([[-0.4993]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7494]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1114]], device='cuda:0')
# action.item() 0.11138719320297241
# action_dist Normal(loc: tensor([[-0.4996]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8098]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6478]], device='cuda:0')
# action.item() -0.6478182673454285
# action_dist Normal(loc: tensor([[-0.5006]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8690]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6346]], device='cuda:0')
# action.item() -0.634556770324707
# action_dist Normal(loc: tensor([[-0.5034]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9267]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.7535]], device='cuda:0')
# action.item() -1.7535380125045776
# action_dist Normal(loc: tensor([[-0.5130]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9526]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.6573]], device='cuda:0')
# action.item() 0.657282829284668
# action_dist Normal(loc: tensor([[-0.5099]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9860]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.5425]], device='cuda:0')
# action.item() -1.5424823760986328
# action_dist Normal(loc: tensor([[-0.4710]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9815]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0871]], device='cuda:0')
# action.item() -0.08706110715866089
# action_dist Normal(loc: tensor([[-0.4171]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9674]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4787]], device='cuda:0')
# action.item() -0.4786922037601471
# action_dist Normal(loc: tensor([[-0.3712]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9370]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.5512]], device='cuda:0')
# action.item() -1.5512031316757202
# action_dist Normal(loc: tensor([[-0.3055]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8973]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-2.3401]], device='cuda:0')
# action.item() -2.340134620666504
# action_dist Normal(loc: tensor([[-0.2387]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8493]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3695]], device='cuda:0')
# action.item() 0.3694944679737091
# action_dist Normal(loc: tensor([[-0.2308]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8164]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-2.3186]], device='cuda:0')
# action.item() -2.3185794353485107
# action_dist Normal(loc: tensor([[-0.1166]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7955]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4689]], device='cuda:0')
# action.item() 0.46891093254089355
# action_dist Normal(loc: tensor([[-0.0853]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8079]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0279]], device='cuda:0')
# action.item() 0.027906842529773712
# action_dist Normal(loc: tensor([[-0.1470]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8142]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2211]], device='cuda:0')
# action.item() -0.2210668921470642
# action_dist Normal(loc: tensor([[-0.1078]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7915]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1490]], device='cuda:0')
# action.item() 0.1490173190832138
# action_dist Normal(loc: tensor([[-0.1276]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7746]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9734]], device='cuda:0')
# action.item() -0.9734362363815308
# action_dist Normal(loc: tensor([[-0.1577]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7716]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5187]], device='cuda:0')
# action.item() 0.5187413096427917
# action_dist Normal(loc: tensor([[-0.1716]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7673]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.7579]], device='cuda:0')
# action.item() 0.7578562498092651
# action_dist Normal(loc: tensor([[-0.1630]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7625]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2287]], device='cuda:0')
# action.item() -0.22866098582744598
# action_dist Normal(loc: tensor([[-0.1411]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7547]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5123]], device='cuda:0')
# action.item() -0.5123419761657715
# action_dist Normal(loc: tensor([[-0.0963]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7382]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0917]], device='cuda:0')
# action.item() -1.091727375984192
# action_dist Normal(loc: tensor([[-0.0412]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7167]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0398]], device='cuda:0')
# action.item() -1.0397695302963257
# action_dist Normal(loc: tensor([[0.0184]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6967]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.8418]], device='cuda:0')
# action.item() 0.8418373465538025
# action_dist Normal(loc: tensor([[0.0773]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6785]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.2332]], device='cuda:0')
# action.item() 0.23320338129997253
# action_dist Normal(loc: tensor([[0.1217]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6635]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5404]], device='cuda:0')
# action.item() 0.5403740406036377
# action_dist Normal(loc: tensor([[0.1501]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6537]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4606]], device='cuda:0')
# action.item() -0.4605834186077118
# action_dist Normal(loc: tensor([[0.1603]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6440]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0844]], device='cuda:0')
# action.item() -1.0844366550445557
# action_dist Normal(loc: tensor([[0.1486]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6325]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1277]], device='cuda:0')
# action.item() -0.12766104936599731
# action_dist Normal(loc: tensor([[0.0904]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6187]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0639]], device='cuda:0')
# action.item() 0.06388185918331146
# action_dist Normal(loc: tensor([[-0.0257]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6052]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5919]], device='cuda:0')
# action.item() -0.5919390320777893
# action_dist Normal(loc: tensor([[-0.1274]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5879]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6352]], device='cuda:0')
# action.item() -0.6352316737174988
# action_dist Normal(loc: tensor([[-0.2312]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5589]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3799]], device='cuda:0')
# action.item() -0.3799476623535156
# action_dist Normal(loc: tensor([[-0.3956]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5651]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1374]], device='cuda:0')
# action.item() 0.13738557696342468
# action_dist Normal(loc: tensor([[-0.5583]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6117]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1749]], device='cuda:0')
# action.item() -1.1749176979064941
# action_dist Normal(loc: tensor([[-0.6232]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6300]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1787]], device='cuda:0')
# action.item() -0.17869889736175537
# action_dist Normal(loc: tensor([[-0.6207]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6588]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1206]], device='cuda:0')
# action.item() -0.12061506509780884
# action_dist Normal(loc: tensor([[-0.5662]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6844]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3174]], device='cuda:0')
# action.item() -0.3174232840538025
# action_dist Normal(loc: tensor([[-0.4883]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7184]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.4837]], device='cuda:0')
# action.item() -1.4836554527282715
# action_dist Normal(loc: tensor([[-0.4717]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7580]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0803]], device='cuda:0')
# action.item() 0.08029419183731079
# action_dist Normal(loc: tensor([[-0.4732]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8118]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.6514]], device='cuda:0')
# action.item() -1.651432752609253
# action_dist Normal(loc: tensor([[-0.4721]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8481]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1537]], device='cuda:0')
# action.item() 0.15374091267585754
# action_dist Normal(loc: tensor([[-0.4852]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8917]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5000]], device='cuda:0')
# action.item() -0.4999591112136841
# action_dist Normal(loc: tensor([[-0.4979]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9176]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2776]], device='cuda:0')
# action.item() -0.2775838077068329
# action_dist Normal(loc: tensor([[-0.4935]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9322]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5636]], device='cuda:0')
# action.item() 0.5636388659477234
# action_dist Normal(loc: tensor([[-0.4558]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9422]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3811]], device='cuda:0')
# action.item() -0.3811475336551666
# action_dist Normal(loc: tensor([[-0.4109]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9243]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3074]], device='cuda:0')
# action.item() 0.3073658347129822
# action_dist Normal(loc: tensor([[-0.3699]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9038]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0648]], device='cuda:0')
# action.item() -0.0647977888584137
# action_dist Normal(loc: tensor([[-0.3018]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8756]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9001]], device='cuda:0')
# action.item() -0.9000867605209351
# action_dist Normal(loc: tensor([[-0.2384]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8362]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.2962]], device='cuda:0')
# action.item() -1.296174168586731
# action_dist Normal(loc: tensor([[-0.2088]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8016]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.7564]], device='cuda:0')
# action.item() 0.7564224600791931
# action_dist Normal(loc: tensor([[-0.1348]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7926]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.5740]], device='cuda:0')
# action.item() -1.5740410089492798
# action_dist Normal(loc: tensor([[-0.1332]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8182]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0372]], device='cuda:0')
# action.item() -1.0371549129486084
# action_dist Normal(loc: tensor([[-0.1356]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8008]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5759]], device='cuda:0')
# action.item() 0.5758560299873352
# action_dist Normal(loc: tensor([[-0.1014]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7804]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-2.1002]], device='cuda:0')
# action.item() -2.100214958190918
# action_dist Normal(loc: tensor([[-0.1526]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7734]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1282]], device='cuda:0')
# action.item() -0.12816625833511353
# action_dist Normal(loc: tensor([[-0.1635]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7673]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.8016]], device='cuda:0')
# action.item() 0.8016365170478821
# action_dist Normal(loc: tensor([[-0.1558]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7623]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7412]], device='cuda:0')
# action.item() -0.7411540746688843
# action_dist Normal(loc: tensor([[-0.1361]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7544]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1317]], device='cuda:0')
# action.item() -0.131747305393219
# action_dist Normal(loc: tensor([[-0.0914]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7383]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2770]], device='cuda:0')
# action.item() -0.2770165205001831
# action_dist Normal(loc: tensor([[-0.0371]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7181]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3166]], device='cuda:0')
# action.item() 0.31659039855003357
# action_dist Normal(loc: tensor([[0.0217]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6997]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4965]], device='cuda:0')
# action.item() -0.4964800179004669
# action_dist Normal(loc: tensor([[0.0744]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6820]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6135]], device='cuda:0')
# action.item() -0.613450288772583
# action_dist Normal(loc: tensor([[0.1186]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6664]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2579]], device='cuda:0')
# action.item() -0.2579369843006134
# action_dist Normal(loc: tensor([[0.1481]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6554]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3468]], device='cuda:0')
# action.item() -0.3468356728553772
# action_dist Normal(loc: tensor([[0.1629]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6463]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1163]], device='cuda:0')
# action.item() 0.11630867421627045
# action_dist Normal(loc: tensor([[0.1552]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6321]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1713]], device='cuda:0')
# action.item() -0.1713479608297348
# action_dist Normal(loc: tensor([[0.0891]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6186]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6324]], device='cuda:0')
# action.item() -0.63243168592453
# action_dist Normal(loc: tensor([[-0.0116]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6072]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.0956]], device='cuda:0')
# action.item() 1.0955857038497925
# action_dist Normal(loc: tensor([[-0.1630]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5834]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0504]], device='cuda:0')
# action.item() -1.0503878593444824
# action_dist Normal(loc: tensor([[-0.2384]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5607]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.6080]], device='cuda:0')
# action.item() 0.608014702796936
# action_dist Normal(loc: tensor([[-0.4806]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5890]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0268]], device='cuda:0')
# action.item() -0.026822000741958618
# action_dist Normal(loc: tensor([[-0.5950]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6269]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2286]], device='cuda:0')
# action.item() -0.22864288091659546
# action_dist Normal(loc: tensor([[-0.6194]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6496]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2944]], device='cuda:0')
# action.item() -0.29443830251693726
# action_dist Normal(loc: tensor([[-0.5841]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6753]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8284]], device='cuda:0')
# action.item() -0.8284031748771667
# action_dist Normal(loc: tensor([[-0.5067]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7028]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8950]], device='cuda:0')
# action.item() -0.8950195908546448
# action_dist Normal(loc: tensor([[-0.4728]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7406]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0914]], device='cuda:0')
# action.item() -0.09136661887168884
# action_dist Normal(loc: tensor([[-0.4667]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7924]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0206]], device='cuda:0')
# action.item() -1.0205632448196411
# action_dist Normal(loc: tensor([[-0.4682]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8324]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1579]], device='cuda:0')
# action.item() -1.1578893661499023
# action_dist Normal(loc: tensor([[-0.4762]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8640]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.4013]], device='cuda:0')
# action.item() -1.4013395309448242
# action_dist Normal(loc: tensor([[-0.4844]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8825]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0809]], device='cuda:0')
# action.item() 0.08093461394309998
# action_dist Normal(loc: tensor([[-0.4905]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9038]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8545]], device='cuda:0')
# action.item() -0.8544572591781616
# action_dist Normal(loc: tensor([[-0.4675]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9043]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1034]], device='cuda:0')
# action.item() -0.10339745879173279
# action_dist Normal(loc: tensor([[-0.4357]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8993]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0762]], device='cuda:0')
# action.item() -1.076245665550232
# action_dist Normal(loc: tensor([[-0.3976]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8709]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.7571]], device='cuda:0')
# action.item() 1.7571055889129639
# action_dist Normal(loc: tensor([[-0.3350]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8634]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4200]], device='cuda:0')
# action.item() 0.4200095534324646
# action_dist Normal(loc: tensor([[-0.2672]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8365]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7294]], device='cuda:0')
# action.item() -0.729351818561554
# action_dist Normal(loc: tensor([[-0.2252]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8086]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4546]], device='cuda:0')
# action.item() -0.45458948612213135
# action_dist Normal(loc: tensor([[-0.1860]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7865]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4103]], device='cuda:0')
# action.item() 0.4102838337421417
# action_dist Normal(loc: tensor([[-0.1527]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8068]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7772]], device='cuda:0')
# action.item() -0.7771731615066528
# action_dist Normal(loc: tensor([[-0.1697]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8184]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0622]], device='cuda:0')
# action.item() -1.0621892213821411
# action_dist Normal(loc: tensor([[-0.1151]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7914]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.9679]], device='cuda:0')
# action.item() 0.9679405093193054
# action_dist Normal(loc: tensor([[-0.1239]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7773]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3348]], device='cuda:0')
# action.item() -0.3347958028316498
# action_dist Normal(loc: tensor([[-0.1479]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7698]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1838]], device='cuda:0')
# action.item() -0.1837874948978424
# action_dist Normal(loc: tensor([[-0.1407]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7642]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.8770]], device='cuda:0')
# action.item() 0.8770173788070679
# action_dist Normal(loc: tensor([[-0.1260]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7579]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5357]], device='cuda:0')
# action.item() -0.535732090473175
# action_dist Normal(loc: tensor([[-0.0964]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7460]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5257]], device='cuda:0')
# action.item() -0.5257489681243896
# action_dist Normal(loc: tensor([[-0.0527]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7291]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.6468]], device='cuda:0')
# action.item() 0.6467743515968323
# action_dist Normal(loc: tensor([[-0.0002]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7111]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1863]], device='cuda:0')
# action.item() -0.18629953265190125
# action_dist Normal(loc: tensor([[0.0506]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6947]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3855]], device='cuda:0')
# action.item() 0.3855491280555725
# action_dist Normal(loc: tensor([[0.0984]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6798]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0016]], device='cuda:0')
# action.item() -0.0016118958592414856
# action_dist Normal(loc: tensor([[0.1378]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6672]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4236]], device='cuda:0')
# action.item() -0.4235841631889343
# action_dist Normal(loc: tensor([[0.1596]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6559]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.2344]], device='cuda:0')
# action.item() -1.234424352645874
# action_dist Normal(loc: tensor([[0.1595]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6437]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0482]], device='cuda:0')
# action.item() -0.04822099208831787
# action_dist Normal(loc: tensor([[0.1121]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6292]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0134]], device='cuda:0')
# action.item() -1.0134148597717285
# action_dist Normal(loc: tensor([[0.0378]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6204]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3319]], device='cuda:0')
# action.item() 0.33186963200569153
# action_dist Normal(loc: tensor([[-0.0959]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6037]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.3267]], device='cuda:0')
# action.item() -1.326672077178955
# action_dist Normal(loc: tensor([[-0.1732]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5881]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5155]], device='cuda:0')
# action.item() 0.5155397057533264
# action_dist Normal(loc: tensor([[-0.3197]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5812]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4160]], device='cuda:0')
# action.item() -0.4160058796405792
# action_dist Normal(loc: tensor([[-0.4876]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6182]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0459]], device='cuda:0')
# action.item() -0.04587492346763611
# action_dist Normal(loc: tensor([[-0.5887]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6433]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5577]], device='cuda:0')
# action.item() -0.557681143283844
# action_dist Normal(loc: tensor([[-0.6070]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6667]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4590]], device='cuda:0')
# action.item() -0.4589986205101013
# action_dist Normal(loc: tensor([[-0.5349]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6916]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.2629]], device='cuda:0')
# action.item() -1.2628647089004517
# action_dist Normal(loc: tensor([[-0.4809]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7199]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0395]], device='cuda:0')
# action.item() -1.0395255088806152
# action_dist Normal(loc: tensor([[-0.4643]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7546]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.4506]], device='cuda:0')
# action.item() -1.4505844116210938
# action_dist Normal(loc: tensor([[-0.4616]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7842]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1393]], device='cuda:0')
# action.item() -0.1392928659915924
# action_dist Normal(loc: tensor([[-0.4643]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8231]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.5640]], device='cuda:0')
# action.item() -1.5640037059783936
# action_dist Normal(loc: tensor([[-0.4722]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8409]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6423]], device='cuda:0')
# action.item() -0.6422655582427979
# action_dist Normal(loc: tensor([[-0.4732]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8563]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2231]], device='cuda:0')
# action.item() -0.22311672568321228
# action_dist Normal(loc: tensor([[-0.4692]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8674]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8133]], device='cuda:0')
# action.item() -0.8133386373519897
# action_dist Normal(loc: tensor([[-0.4555]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8639]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9104]], device='cuda:0')
# action.item() -0.9104247093200684
# action_dist Normal(loc: tensor([[-0.4147]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8462]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9425]], device='cuda:0')
# action.item() -0.942463755607605
# action_dist Normal(loc: tensor([[-0.3521]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8177]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.6380]], device='cuda:0')
# action.item() 0.6380074620246887
# action_dist Normal(loc: tensor([[-0.2939]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8018]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9057]], device='cuda:0')
# action.item() -0.9056987166404724
# action_dist Normal(loc: tensor([[-0.2387]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7856]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0429]], device='cuda:0')
# action.item() -1.0429376363754272
# action_dist Normal(loc: tensor([[-0.2815]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7893]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2013]], device='cuda:0')
# action.item() -0.20133668184280396
# action_dist Normal(loc: tensor([[-0.2646]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8110]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0394]], device='cuda:0')
# action.item() 0.03939962387084961
# action_dist Normal(loc: tensor([[-0.2061]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8047]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6321]], device='cuda:0')
# action.item() -0.6321350336074829
# action_dist Normal(loc: tensor([[-0.1460]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7913]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2122]], device='cuda:0')
# action.item() -0.21223601698875427
# action_dist Normal(loc: tensor([[-0.1404]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7742]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3513]], device='cuda:0')
# action.item() 0.35134071111679077
# action_dist Normal(loc: tensor([[-0.1293]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7661]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8830]], device='cuda:0')
# action.item() -0.8829565048217773
# action_dist Normal(loc: tensor([[-0.0903]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7535]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0962]], device='cuda:0')
# action.item() -0.09615378081798553
# action_dist Normal(loc: tensor([[-0.0587]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7420]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0819]], device='cuda:0')
# action.item() -0.08185645937919617
# action_dist Normal(loc: tensor([[-0.0230]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7282]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5521]], device='cuda:0')
# action.item() 0.5520559549331665
# action_dist Normal(loc: tensor([[0.0181]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7133]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5058]], device='cuda:0')
# action.item() 0.5057703256607056
# action_dist Normal(loc: tensor([[0.0568]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7001]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0305]], device='cuda:0')
# action.item() -0.03054579347372055
# action_dist Normal(loc: tensor([[0.0925]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6881]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1983]], device='cuda:0')
# action.item() -0.19833192229270935
# action_dist Normal(loc: tensor([[0.1091]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6746]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0906]], device='cuda:0')
# action.item() 0.0905657559633255
# action_dist Normal(loc: tensor([[0.1028]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6652]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0148]], device='cuda:0')
# action.item() -0.014762639999389648
# action_dist Normal(loc: tensor([[0.0726]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6567]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6584]], device='cuda:0')
# action.item() -0.6583791971206665
# action_dist Normal(loc: tensor([[0.0066]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6465]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5066]], device='cuda:0')
# action.item() 0.5066316723823547
# action_dist Normal(loc: tensor([[-0.1021]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6294]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4163]], device='cuda:0')
# action.item() 0.4163346588611603
# action_dist Normal(loc: tensor([[-0.2085]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6185]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4862]], device='cuda:0')
# action.item() 0.48620152473449707
# action_dist Normal(loc: tensor([[-0.2907]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6186]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1637]], device='cuda:0')
# action.item() -0.16369953751564026
# action_dist Normal(loc: tensor([[-0.4063]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6431]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8144]], device='cuda:0')
# action.item() -0.8143570423126221
# action_dist Normal(loc: tensor([[-0.5111]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6579]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3330]], device='cuda:0')
# action.item() -0.3329799175262451
# action_dist Normal(loc: tensor([[-0.5559]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6723]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5489]], device='cuda:0')
# action.item() -0.5488576889038086
# action_dist Normal(loc: tensor([[-0.5368]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6974]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1496]], device='cuda:0')
# action.item() -1.1496267318725586
# Iteration 0:   0%|▎                                                                    | 1/200 [00:08<27:50,  8.39s/it]
# ...
# action tensor([[-1.1688]], device='cuda:0')
# action.item() -1.1688437461853027
# action_dist Normal(loc: tensor([[-0.3252]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8582]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.5368]], device='cuda:0')
# action.item() 0.5367565751075745
# action_dist Normal(loc: tensor([[-0.2662]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8256]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.6602]], device='cuda:0')
# action.item() 1.6602022647857666
# action_dist Normal(loc: tensor([[-0.1735]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8088]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.3673]], device='cuda:0')
# action.item() -0.36728373169898987
# action_dist Normal(loc: tensor([[-0.1190]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8019]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.4842]], device='cuda:0')
# action.item() 1.484248161315918
# action_dist Normal(loc: tensor([[-0.1542]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8009]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4636]], device='cuda:0')
# action.item() 0.4636216163635254
# action_dist Normal(loc: tensor([[-0.2199]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7849]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.4291]], device='cuda:0')
# action.item() 1.4290893077850342
# action_dist Normal(loc: tensor([[-0.1800]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7747]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.2461]], device='cuda:0')
# action.item() 0.2461114078760147
# action_dist Normal(loc: tensor([[-0.1757]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7630]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5915]], device='cuda:0')
# action.item() -0.5915480852127075
# action_dist Normal(loc: tensor([[-0.2275]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7596]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0760]], device='cuda:0')
# action.item() 0.07603220641613007
# action_dist Normal(loc: tensor([[-0.2514]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7482]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.2711]], device='cuda:0')
# action.item() -1.2710870504379272
# action_dist Normal(loc: tensor([[-0.2881]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7392]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9203]], device='cuda:0')
# action.item() -0.9203197956085205
# action_dist Normal(loc: tensor([[-0.2826]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7291]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0127]], device='cuda:0')
# action.item() 0.012680262327194214
# action_dist Normal(loc: tensor([[-0.2526]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7137]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.1632]], device='cuda:0')
# action.item() 0.16324755549430847
# action_dist Normal(loc: tensor([[-0.1953]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6900]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1767]], device='cuda:0')
# action.item() -0.17666834592819214
# action_dist Normal(loc: tensor([[-0.1310]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6673]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1649]], device='cuda:0')
# action.item() -1.1649004220962524
# action_dist Normal(loc: tensor([[-0.0794]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6473]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.4983]], device='cuda:0')
# action.item() 0.4983179569244385
# action_dist Normal(loc: tensor([[-0.0380]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6356]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1442]], device='cuda:0')
# action.item() -0.14418599009513855
# action_dist Normal(loc: tensor([[-0.0097]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6282]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.0719]], device='cuda:0')
# action.item() 1.0718928575515747
# action_dist Normal(loc: tensor([[0.0177]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6235]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.6676]], device='cuda:0')
# action.item() -0.6676220297813416
# action_dist Normal(loc: tensor([[0.0076]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6178]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.0153]], device='cuda:0')
# action.item() 1.0153088569641113
# action_dist Normal(loc: tensor([[0.0074]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6168]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.9052]], device='cuda:0')
# action.item() -0.9051936268806458
# action_dist Normal(loc: tensor([[-0.0351]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6079]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.4994]], device='cuda:0')
# action.item() -1.4994438886642456
# action_dist Normal(loc: tensor([[-0.1183]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6013]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0066]], device='cuda:0')
# action.item() -0.006643317639827728
# action_dist Normal(loc: tensor([[-0.1961]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5926]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.2485]], device='cuda:0')
# action.item() 0.24853365123271942
# action_dist Normal(loc: tensor([[-0.2539]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5597]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.0742]], device='cuda:0')
# action.item() 0.07416057586669922
# action_dist Normal(loc: tensor([[-0.4026]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5508]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1112]], device='cuda:0')
# action.item() -1.1112443208694458
# action_dist Normal(loc: tensor([[-0.5129]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.5823]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7293]], device='cuda:0')
# action.item() -0.7292968034744263
# action_dist Normal(loc: tensor([[-0.5739]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6172]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8770]], device='cuda:0')
# action.item() -0.8770153522491455
# action_dist Normal(loc: tensor([[-0.5931]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6482]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.2235]], device='cuda:0')
# action.item() 0.2234891653060913
# action_dist Normal(loc: tensor([[-0.5900]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.6882]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1193]], device='cuda:0')
# action.item() -1.119342565536499
# action_dist Normal(loc: tensor([[-0.5738]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7122]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.6380]], device='cuda:0')
# action.item() 0.638037919998169
# action_dist Normal(loc: tensor([[-0.4844]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.7526]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1104]], device='cuda:0')
# action.item() -0.11035767197608948
# action_dist Normal(loc: tensor([[-0.4676]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8122]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.2618]], device='cuda:0')
# action.item() -0.26175040006637573
# action_dist Normal(loc: tensor([[-0.4764]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8817]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.5290]], device='cuda:0')
# action.item() -0.5290086269378662
# action_dist Normal(loc: tensor([[-0.4931]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9534]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.0596]], device='cuda:0')
# action.item() -1.0595797300338745
# action_dist Normal(loc: tensor([[-0.5120]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0165]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.4766]], device='cuda:0')
# action.item() -1.4766321182250977
# action_dist Normal(loc: tensor([[-0.5397]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0486]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.7172]], device='cuda:0')
# action.item() -0.7172020673751831
# action_dist Normal(loc: tensor([[-0.5563]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0693]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.8775]], device='cuda:0')
# action.item() -0.8774826526641846
# action_dist Normal(loc: tensor([[-0.5334]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0686]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.9527]], device='cuda:0')
# action.item() 0.9526812434196472
# action_dist Normal(loc: tensor([[-0.4942]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0645]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.9807]], device='cuda:0')
# action.item() -1.9807336330413818
# action_dist Normal(loc: tensor([[-0.4523]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[1.0063]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.1502]], device='cuda:0')
# action.item() -0.15015962719917297
# action_dist Normal(loc: tensor([[-0.3948]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9686]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[1.4957]], device='cuda:0')
# action.item() 1.495657205581665
# action_dist Normal(loc: tensor([[-0.3433]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.9425]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3432]], device='cuda:0')
# action.item() 0.3432086110115051
# action_dist Normal(loc: tensor([[-0.3183]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8990]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.0520]], device='cuda:0')
# action.item() -0.05195045471191406
# action_dist Normal(loc: tensor([[-0.3102]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8479]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-0.4085]], device='cuda:0')
# action.item() -0.40854695439338684
# action_dist Normal(loc: tensor([[-0.1933]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8164]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[0.3839]], device='cuda:0')
# action.item() 0.3839205503463745
# action_dist Normal(loc: tensor([[-0.1126]], device='cuda:0', grad_fn=<MulBackward0>), scale: tensor([[0.8108]], device='cuda:0', grad_fn=<SoftplusBackward0>))
# action tensor([[-1.1006]], device='cuda:0')
# action.item() -1.1005719900131226
# action_dist
# Iteration 0:   1%|▋                                                                    | 2/200 [00:10<17:18,  5.24s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 28
#      24 action_dim = env.action_space.shape[0]  # 连续动作空间
#      25 agent = PPOContinuous(state_dim, hidden_dim, action_dim, actor_lr, critic_lr,
#      26                       lmbda, epochs, eps, gamma, device)
# ---> 28 return_list = rl_utils.train_on_policy_agent(env, agent, num_episodes)
#      30 # Iteration 0: 100%|██████████| 200/200 [02:15<00:00,  1.47it/s, episode=200,
#      31 # return=-984.137]
#      32 # Iteration 1: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=400,
#    (...)
#      48 # Iteration 9: 100%|██████████| 200/200 [02:17<00:00,  1.45it/s, episode=2000,
#      49 # return=-248.958]
#
# File E:\2025work\rl\rl_utils.py:71, in train_on_policy_agent(env, agent, num_episodes)
#      69 done = False
#      70 while not done:#在一个回合中不断交互
# ---> 71     action = agent.take_action(state) #选择一个策略，具体选什么需要参考算法定义
#      72     #next_state, reward, done, _ = env.step(action)
#      73     next_state, reward, done, _ = env_step(env,action)
#
# Cell In[2], line 44, in PPOContinuous.take_action(self, state)
#      42 action_dist = torch.distributions.Normal(mu, sigma)
#      43 action = action_dist.sample()
# ---> 44 print("action_dist",action_dist)
#      45 print("action",action)
#      46 print("action.item()",action.item())
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\distributions\distribution.py:310, in Distribution.__repr__(self)
#     308 def __repr__(self):
#     309     param_names = [k for k, _ in self.arg_constraints.items() if k in self.__dict__]
# --> 310     args_string = ', '.join(['{}: {}'.format(p, self.__dict__[p]
#     311                             if self.__dict__[p].numel() == 1
#     312                             else self.__dict__[p].size()) for p in param_names])
#     313     return self.__class__.__name__ + '(' + args_string + ')'
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\distributions\distribution.py:310, in <listcomp>(.0)
#     308 def __repr__(self):
#     309     param_names = [k for k, _ in self.arg_constraints.items() if k in self.__dict__]
# --> 310     args_string = ', '.join(['{}: {}'.format(p, self.__dict__[p]
#     311                             if self.__dict__[p].numel() == 1
#     312                             else self.__dict__[p].size()) for p in param_names])
#     313     return self.__class__.__name__ + '(' + args_string + ')'
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\_tensor.py:660, in Tensor.__format__(self, format_spec)
#     658 if self.dim() == 0 and not self.is_meta:
#     659     return self.item().__format__(format_spec)
# --> 660 return object.__format__(self, format_spec)
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\_tensor.py:338, in Tensor.__repr__(self, tensor_contents)
#     335     return handle_torch_function(Tensor.__repr__, (self,), self,
#     336                                  tensor_contents=tensor_contents)
#     337 # All strings are unicode in Python 3.
# --> 338 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\_tensor_str.py:481, in _str(self, tensor_contents)
#     479 def _str(self, *, tensor_contents=None):
#     480     with torch.no_grad():
# --> 481         return _str_intern(self, tensor_contents=tensor_contents)
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\_tensor_str.py:447, in _str_intern(inp, tensor_contents)
#     445                     tensor_str = _tensor_str(self.to_dense(), indent)
#     446                 else:
# --> 447                     tensor_str = _tensor_str(self, indent)
#     449 if self.layout != torch.strided:
#     450     suffixes.append('layout=' + str(self.layout))
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\_tensor_str.py:270, in _tensor_str(self, indent)
#     268     return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     269 else:
# --> 270     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     271     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File E:\anaconda\envs\rl\lib\site-packages\torch\_tensor_str.py:119, in _Formatter.__init__(self, tensor)
#     116         self.int_mode = False
#     117         break
# --> 119 if self.int_mode:
#     120     # in int_mode for floats, all numbers are integers, and we append a decimal to nonfinites
#     121     # to indicate that the tensor is of floating type. add 1 to the len to account for this.
#     122     if nonzero_finite_max / nonzero_finite_min > 1000. or nonzero_finite_max > 1.e8:
#     123         self.sci_mode = True
#
# KeyboardInterrupt:

# %%
episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PPO on {}'.format(env_name))
plt.show()

mv_return = rl_utils.moving_average(return_list, 21)
plt.plot(episodes_list, mv_return)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PPO on {}'.format(env_name))
plt.show()
